# %%
from openai import OpenAI
import os

# %%
client = OpenAI(api_key='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')
        
# Make a simple test request
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Hello, is this working?"}
    ]
)
        
# Check if we got a response
if response and response.choices[0].message.content:
    print("API is working! Response:", response.choices[0].message.content)
    return True
else:
    print("API response was empty or invalid")
    return False
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 client = OpenAI(api_key='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')
#       3 # Make a simple test request
# ----> 4 response = client.chat.completions.create(
#       5     model="gpt-4o-mini",
#       6     messages=[
#       7         {"role": "system", "content": "You are a helpful assistant."},
#       8         {"role": "user", "content": "Hello, is this working?"}
#       9     ]
#      10 )
#      12 # Check if we got a response
#      13 if response and response.choices[0].message.content:
#
# File ~\anaconda3\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
# ...
